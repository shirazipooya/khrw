# %%
import pandas as pd
pd.options.display.max_columns = None

import geopandas as gpd
import json

# %%
data = pd.read_csv(filepath_or_buffer="database.csv")
columns = ["st_id", "st_en_name", "st_fa_name", "st_type", "sub_basin", "study_area_name", "study_area_code", 
           "decimal_degrees_x", "decimal_degrees_y", "surface_elevation", "sample_type"]
data = data[columns]

data.drop_duplicates(keep = "first", inplace = True)


data
# Out:
#     st_id     st_en_name  st_fa_name       st_type        sub_basin  \
# 0     AKH       Akhlamad       اخلمد  Rain Station         Quaraqum
# 33    BZG       Bazangan      بزنگان    ET Station         Quaraqum
# 78    CHK       Chakaneh        چکنه  Rain Station         Quaraqum
# 142   DRZ         Dargaz        درگز    ET Station         Quaraqum
# 172   FRZ         Freizi       فریزی  Rain Station         Quaraqum
# 224   HTT        Hatiteh       حطیطه  Rain Station  Falat-e-Markazi
# 255   KLJ  Kalat-e-Jafar  کلاته جعفر    ET Station         Quaraqum
# 309  SHRD        Shirbad      شیرباد    ET Station         Quaraqum
# 311   KRD         Kardeh       کارده    ET Station         Quaraqum
# 316   KHR      Kheyrabad     خیرآباد    ET Station         Quaraqum
# 318   MRK        Mareshk       مارشک    ET Station         Quaraqum
# 364   MSD        Mashhad        مشهد  Rain Station         Quaraqum
# 389   MZD      Mazdavand     مزدواند    ET Station         Quaraqum
# ...

# %%
list(data['study_area_code'].unique())
# Out:
# [6007, 6003, 6001, 4735, 6011, 6004, 6002, 1708]

# %%
file_path = "~/w/khrw/ShapeFiles/AreaStudy/AreaStudy.shp",
os_moteval = 'خراسان رضوي',
mah_code = None

# %%
geodf = gpd.read_file(file_path, encoding='windows-1256')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-52e0ba029fae> in <module>
# ----> 1 geodf = gpd.read_file(file_path, encoding='windows-1256')
#
# ~/w/khrw/.venv/lib/python3.9/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     158
#     159     with fiona_env():
# --> 160         with reader(path_or_bytes, **kwargs) as features:
#     161
#     162             # In a future Fiona release the crs attribute of features will
#
# ~/w/khrw/.venv/lib/python3.9/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     398     def wrapper(*args, **kwargs):
#     399         if local._env:
# --> 400             return f(*args, **kwargs)
#     401         else:
#     402             if isinstance(args[0], str):
#
# ...
